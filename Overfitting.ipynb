# %% [markdown]
# <a href="https://colab.research.google.com/github/madarasw/ML_Basics/blob/main/Overfitting.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Goals
#
# the situations where overfitting can occur
# some of the solutions

# %%
# mount google drive

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
import sys
import numpy as np
import matplotlib.pyplot as plt

# Add folder to Python path
sys.path.append("/content/drive/MyDrive/Colab Notebooks")

# Apply style
plt.style.use('/content/drive/MyDrive/Colab Notebooks/deeplearning.mplstyle')

# %%
# %matplotlib inline
from ipywidgets import Output
from plt_overfit import overfit_example, output

# %%
plt.close("all")
display(output)
ofit = overfit_example(False)
# Out:
# Output()
